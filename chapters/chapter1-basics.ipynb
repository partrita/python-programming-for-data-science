# %% [markdown]
# ![](../docs/banner.png)

# %% [markdown]
# # 1장: 파이썬 기초

# %% [markdown]
# <h2>장 구성<span class="tocSkip"></span></h2>
# <hr>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Introduction" data-toc-modified-id="1.-Introduction-1">1. 소개</a></span></li><li><span><a href="#2.-Basic-Python-Data-Types" data-toc-modified-id="2.-Basic-Python-Data-Types-2">2. 기본 파이썬 데이터 타입</a></span></li><li><span><a href="#3.-Lists-and-Tuples" data-toc-modified-id="3.-Lists-and-Tuples-3">3. 리스트와 튜플</a></span></li><li><span><a href="#4.-String-Methods" data-toc-modified-id="4.-String-Methods-4">4. 문자열 메서드</a></span></li><li><span><a href="#5.-Dictionaries" data-toc-modified-id="5.-Dictionaries-5">5. 딕셔너리</a></span></li><li><span><a href="#6.-Empties" data-toc-modified-id="6.-Empties-6">6. 빈 객체들</a></span></li><li><span><a href="#7.-Conditionals" data-toc-modified-id="7.-Conditionals-7">7. 조건문</a></span></li></ul></div>

# %% [markdown]
# ## 학습 목표
# <hr>

# %% [markdown]
# - `int`, `float`, `문자열`, `리스트`, `dict`, `튜플` 등 표준 파이썬 데이터 타입을 생성하고 설명하며 구분할 수 있습니다.
# - 숫자 값에 대해 `+`, `-`, `*`, `**`와 같은 산술 연산을 수행할 수 있습니다.
# - 문자열을 조작하기 위해 `.lower()`, `.split()`과 같은 기본적인 문자열 연산을 수행할 수 있습니다.
# - 비교 연산자(`==`, `!=`, `>` 등)와 불리언 연산자(`and`, `or`, `not`)를 사용하여 불리언 값을 계산할 수 있습니다.
# - 튜플, 리스트, 문자열, 딕셔너리에 값을 할당하고, 인덱싱, 슬라이싱 및 서브셋을 추출할 수 있습니다.
# - `if`, `elif`, `else`를 사용하여 조건문을 작성할 수 있습니다.
# - 들여쓰기 수준으로 코드 블록을 식별할 수 있습니다.
# - `리스트`와 같은 가변(mutable) 객체와 `튜플`과 같은 불변(immutable) 객체의 차이점을 설명할 수 있습니다.

# %% [markdown]
# ## 1. 소개
# <hr>

# %% [markdown]
# 이 웹사이트에서 제공하는 자료는 파이썬에 대한 사전 지식이 없다고 가정합니다. 프로그래밍 개념이나 다른 프로그래밍 언어에 대한 경험이 있으면 도움이 되지만, 내용을 이해하는 데 필수적인 것은 아닙니다.
#
# 이 웹사이트는 다음으로 구성되어 있습니다:
# 1. **장(Chapters)**: 핵심 내용을 담고 있습니다. 편하실 때 읽어보세요.
# 2. **연습 문제(Practice Exercises)**: 각 장을 보완하기 위한 선택적인 연습 문제 세트입니다(해설 포함). 개념을 확실히 익히기 위해 연습 문제를 직접 풀어보세요.

# %% [markdown]
# ## 2. 기본 파이썬 데이터 타입
# <hr>

# %% [markdown]
# A **value** is a piece of data that a computer program works with such as a number or 텍스트. There are different **types** of values: `42` is an 정수 and `"Hello!"` is a 문자열. A **variable** is a name that refers to a value. In mathematics and statistics, we usually use variable names like $x$ and $y$. In Python, we can use any word as a variable name as long as it starts with a letter or an underscore. However, it should not be a [reserved word](https://docs.python.org/3.3/reference/lexical_analysis.html#keywords) in Python such as `for`, `while`, `class`, `lambda`, etc. as these words encode special functionality in Python that we don't want to overwrite!
#
# 변수를 어떤 정보(단일 숫자, 벡터, 문자열 등)를 담는 상자라고 생각하면 이해하기 쉽습니다. 우리는 **할당 연산자(assignment operator)** `=`를 사용하여 변수에 값을 할당합니다.
#
# ![](img/chapter1/box.png)
#
# 이미지 출처: [medium.com](https://www.google.com/url?sa=i&url=https%3A%2F%2Fmedium.com%2F%40stevenpcurtis.sc%2Fwhat-is-a-variable-3447ac1331b9&psig=AOvVaw3YbYfgb7XFOJ_sHP5eliob&ust=1595365663851000&source=images&cd=vfe&ved=0CA0QjhxqFwoTCMi8nrfe3OoCFQAAAAAdAAAAABAZ)
#
# ::: {.callout-tip}
# 표준 내장 파이썬 데이터 타입에 대한 요약은 [파이썬 3 문서](https://docs.python.org/3/library/stdtypes.html)를 참고하세요.
# :::

# %% [markdown]
# ### 주요 내장 파이썬 데이터 타입
#
# | 영어 명칭          | 타입 명칭  | 타입 범주  | 설명                                   | 예시                                    |
# | :-------------------- | :--------- | :------------- | :-------------------------------------------- | :----------------------------------------- |
# | 정수               | `int`      | 숫자 타입   | 양수/음수 정수               | `42`                                       |
# | 부동 소수점 수 | `float`    | 숫자 타입   | 십진수 형태의 실수                   | `3.14159`                                  |
# | 불리언               | `bool`     | 불리언 값 | 참 또는 거짓                                 | `True`                                     |
# | 문자열                | `str`      | 시퀀스 타입  | 텍스트                                          | `"I Can Has Cheezburger?"`                 |
# | 리스트                  | `리스트`     | 시퀀스 타입  | 객체들의 모음 - 가변(mutable) 및 정렬됨   | `['Ali', 'Xinyi', 'Miriam']`               |
# | 튜플                 | `튜플`    | 시퀀스 타입  | 객체들의 모음 - 불변(immutable) 및 정렬됨 | `('Thursday', 6, 9, 2018)`                 |
# | 딕셔너리            | `dict`     | 매핑 타입   | 키-값 쌍의 매핑                    | `{'name':'DSCI', 'code':511, 'credits':2}` |
# | None                  | `NoneType` | Null 객체    | 값이 없음을 나타냄                           | `None`                                     |

# %% [markdown]
# ### 숫자 데이터 타입

# %% [markdown]
# 파이썬에는 세 가지 구별되는 숫자 타입이 있습니다: 정수(정수s), 부동 소수점 수(부동 소수점 수s), 복소수(complex numbers, 여기서는 다루지 않음). `type()`을 사용하여 객체의 타입을 확인할 수 있고, `print()`를 사용하여 객체의 값을 출력할 수 있습니다.

# %%
x = 42

# %%
type(x)
# Out:
# int

# %%
print(x)
# Out:
# 42

# %% [markdown]
# Jupyter/IPython(대화형 파이썬)에서는 셀의 마지막 줄이 자동으로 화면에 출력되므로 `print()`를 명시적으로 호출할 필요가 없습니다.

# %%
x  # Anything after the pound/hash symbol is a comment and will not be run
# Out:
# 42

# %%
pi = 3.14159
pi
# Out:
# 3.14159

# %%
type(pi)
# Out:
# float

# %% [markdown]
# ### 산술 연산자
#
# Below is a table of the syntax for common arithmetic operations in Python:
#
# | 연산자 |   설명    |
# | :------: | :--------------: |
# |   `+`    |     더하기     |
# |   `-`    |   빼기    |
# |   `*`    |  곱하기  |
# |   `/`    |     나누기     |
# |   `**`   |  거듭제곱  |
# |   `//`   | 정수 나누기 / floor 나누기 |
# |   `%`    |      나머지(모듈로) 연산      |
#
# 이 연산자들을 숫자 타입에 적용해보고 결과를 살펴봅시다.

# %%
1 + 2 + 3 + 4 + 5  # add
# Out:
# 15

# %%
2 * 3.14159  # multiply
# Out:
# 6.28318

# %%
2 ** 10  # exponent
# Out:
# 1024

# %% [markdown]
# 나눗셈은 예상과 다른 데이터 타입(`dtype`)을 생성할 수 있습니다. 예를 들어 `int`를 `float`으로 바꿉니다.

# %%
int_2 = 2
type(int_2)
# Out:
# int

# %%
int_2 / int_2  # divison
# Out:
# 1.0

# %%
type(int_2 / int_2)
# Out:
# float

# %% [markdown]
# 하지만 `//` 구문을 사용하면 "정수 나눗셈"(내림 나눗셈)을 수행하고 `int` 데이터 타입을 유지할 수 있습니다. 이 연산은 항상 내림을 합니다.

# %%
101 / 2
# Out:
# 50.5

# %%
101 // 2  # "floor division" - always rounds down
# Out:
# 50

# %% [markdown]
# 결과를 정수로 내림(floor)하기 때문에 이를 "정수 나눗셈" 또는 "내림 나눗셈"이라고 부릅니다.

# %%
int(101 / 2)
# Out:
# 50

# %% [markdown]
# "%"(모듈로) 연산자는 나눗셈 후의 나머지를 반환합니다.

# %%
100 % 2  # "100 mod 2", or the remainder when 100 is divided by 2
# Out:
# 0

# %%
101 % 2  # "101 mod 2", or the remainder when 101 is divided by 2
# Out:
# 1

# %%
100.5 % 2
# Out:
# 0.5

# %% [markdown]
# ### None
#
# NoneType은 파이썬에서 고유한 타입입니다. 오직 `None`이라는 하나의 값만 가질 수 있으며, 값이 없음을 나타냅니다. 나중에 다시 자세히 살펴보겠습니다.

# %%
x = None

# %%
print(x)
# Out:
# None

# %%
type(x)
# Out:
# NoneType

# %% [markdown]
# ### 문자열
#
# 텍스트는 문자열(문자열)이라는 데이터 타입으로 저장됩니다. 문자열은 문자의 시퀀스로 생각할 수 있습니다.
#
# ::: {.callout-tip}
# 사실 문자열은 유니코드 코드 포인트의 시퀀스입니다. 관심이 있다면 유니코드에 대한 이 [훌륭한 블로그 포스트](https://www.joelonsoftware.com/2003/10/08/the-absolute-minimum-every-software-developer-absolutely-positively-must-know-about-unicode-and-character-sets-no-excuses/)를 확인해 보세요.
# :::
#
# 문자열은 다음 중 하나로 감싸서 작성합니다:
#   - 작은따옴표, 예: `'Hello'`
#   - 큰따옴표, 예: `"Goodbye"`
#
# 두 방법 사이에 차이는 없지만, 둘 다 사용할 수 있어 유용한 경우가 있습니다(아래 참고)! 또한 함수 문서화(doc문자열)에 주로 사용되는 세 개의 큰따옴표(`"""`)도 있습니다.

# %%
my_name = "Tomas Beuzen"

# %%
my_name
# Out:
# 'Tomas Beuzen'

# %%
type(my_name)
# Out:
# str

# %%
course = 'DSCI 511'

# %%
course
# Out:
# 'DSCI 511'

# %%
type(course)
# Out:
# str

# %% [markdown]
# 문자열 안에 따옴표나 아포스트로피가 포함되어 있다면, 작은따옴표와 큰따옴표를 조합하여 문자열을 정의할 수 있습니다.

# %%
sentence = "It's a rainy day."

# %%
sentence
# Out:
# "It's a rainy day."

# %%
type(sentence)
# Out:
# str

# %%
quote = 'Donald Knuth: "Premature optimization is the root of all evil."'

# %%
quote
# Out:
# 'Donald Knuth: "Premature optimization is the root of all evil."'

# %% [markdown]
# ### 불리언
#
# 불리언(bool) 타입은 `True`(참)와 `False`(거짓)라는 두 가지 값을 가집니다.

# %%
the_truth = True

# %%
the_truth
# Out:
# True

# %%
type(the_truth)
# Out:
# bool

# %%
lies = False

# %%
lies
# Out:
# False

# %%
type(lies)
# Out:
# bool

# %% [markdown]
# ### 비교 연산자
#
# 비교 연산자를 사용하여 객체를 비교할 수 있으며, 그 결과로 불리언 값을 반환받습니다.
#
# | 연산자  | 설명                          |
# | :-------- | :----------------------------------- |
# | `x == y ` | `x`와 `y`가 같습니까?                 |
# | `x != y`  | `x`와 `y`가 같지 않습니까?             |
# | `x > y`   | `x`가 `y`보다 큽니까?             |
# | `x >= y`  | `x`가 `y`보다 크거나 같습니까? |
# | `x < y`   | `x`가 `y`보다 작습니까?                |
# | `x <= y`  | `x`가 `y`보다 작거나 같습니까?    |
# | `x is y`  | `x`가 `y`와 같은 객체입니까?       |

# %%
2 < 3
# Out:
# True

# %%
"Deep learning" == "Solve all the world's problems"
# Out:
# False

# %%
2 != "2"
# Out:
# True

# %%
2 is 2
# Out:
# True

# %%
2 == 2.0
# Out:
# True

# %% [markdown]
# ### 불리언 연산자s
#
# 또한 불리언 결과를 반환하는 소위 "불리언 연산자"가 있습니다.
#
# | 연산자 | 설명 |
# | :---: | :--- |
# |`x and y`| `x`와 `y`가 모두 참입니까? |
# |`x or y` | `x`와 `y` 중 적어도 하나가 참입니까? |
# | `not x` | `x`가 거짓입니까? |

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
("Python 2" != "Python 3") and (2 <= 3)
# Out:
# True

# %%
True
# Out:
# True

# %%
not True
# Out:
# False

# %%
not not True
# Out:
# True

# %% [markdown]
# ::: {.callout-note}
# Python also has [bitwise operators](https://wiki.python.org/moin/Bitwise연산자s) like `&` and `|`. Bitwise operators literally compare the bits of two 정수s. That's beyond the scope of this course but I've included a code snippet below to show you them in action.
# :::

# %%
print(f"Bit representation of the number 5: {5:0b}")
print(f"Bit representation of the number 4: {4:0b}")
print(f"                                    ↓↓↓")
print(f"                                    {5 & 4:0b}")
print(f"                                     ↓ ")
print(f"                                     {5 & 4}")
# Out:
# Bit representation of the number 5: 101
# Bit representation of the number 4: 100
#                                     ↓↓↓
#                                     100
#                                      ↓
#                                      4

# %% [markdown]
# ### 형변환(Casting)
#
# 때로는 값의 타입을 한 타입에서 다른 타입으로 명시적으로 **형변환(cast)**해야 할 때가 있습니다. `str()`, `int()`, `float()`와 같은 함수를 사용하여 이를 수행할 수 있습니다. 파이썬은 변환을 시도하며, 불가능할 경우 에러를 발생시킵니다.

# %%
x = 5.0
type(x)
# Out:
# float

# %%
x = int(5.0)
x
# Out:
# 5

# %%
type(x)
# Out:
# int

# %%
x = str(5.0)
x
# Out:
# '5.0'

# %%
type(x)
# Out:
# str

# %%
str(5.0) == 5.0
# Out:
# False

# %%
int(5.3)
# Out:
# 5

# %%
float("hello")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-7124e8e12e61> in <module>
# ----> 1 float("hello")
#
# ValueError: could not convert string to float: 'hello'

# %% [markdown]
# ## 3. 리스트와 튜플
# <hr>

# %% [markdown]
# 리스트와 튜플을 사용하면 하나의 객체에 여러 요소(elements)를 저장할 수 있습니다. 각 요소들은 순서(ordered)를 가지고 있습니다. 먼저 리스트부터 살펴보겠습니다. 리스트는 대괄호 `[]`로 정의합니다.

# %%
my_list = [1, 2, "THREE", 4, 0.5]

# %%
my_list
# Out:
# [1, 2, 'THREE', 4, 0.5]

# %%
type(my_list)
# Out:
# list

# %% [markdown]
# 리스트는 어떤 데이터 타입이든 담을 수 있으며, 심지어 다른 리스트도 포함할 수 있습니다!

# %%
another_list = [1, "two", [3, 4, "five"], True, None, {"key": "value"}]
another_list
# Out:
# [1, 'two', [3, 4, 'five'], True, None, {'key': 'value'}]

# %% [markdown]
# 리스트의 길이는 `len()` 함수로 확인할 수 있습니다.

# %%
len(my_list)
# Out:
# 5

# %% [markdown]
# 튜플은 리스트와 비슷해 보이지만 핵심적인 차이점이 있습니다(불변(immutable) 객체라는 점인데, 잠시 후에 자세히 다루겠습니다). 튜플은 소괄호 `()`로 정의합니다.

# %%
today = (1, 2, "THREE", 4, 0.5)

# %%
today
# Out:
# (1, 2, 'THREE', 4, 0.5)

# %%
type(today)
# Out:
# tuple

# %%
len(today)
# Out:
# 5

# %% [markdown]
# ### 시퀀스 인덱싱과 슬라이싱
#
# 대괄호 구문을 사용하여 리스트, 튜플, 또는 문자열 내부의 값에 접근할 수 있습니다. 파이썬은 **0부터 시작하는 인덱싱(zero-based indexing)**을 사용합니다. 즉, 첫 번째 요소의 위치는 1이 아니라 0입니다.

# %%
my_list
# Out:
# [1, 2, 'THREE', 4, 0.5]

# %%
my_list[0]
# Out:
# 1

# %%
my_list[2]
# Out:
# 'THREE'

# %%
len(my_list)
# Out:
# 5

# %%
my_list[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-84-075ca585e721> in <module>
# ----> 1 my_list[5]
#
# IndexError: list index out of range

# %% [markdown]
# 음수 인덱스를 사용하여 리스트의 끝에서부터 거꾸로 셀 수 있습니다.

# %%
my_list
# Out:
# [1, 2, 'THREE', 4, 0.5]

# %%
my_list[-1]
# Out:
# 0.5

# %%
my_list[-2]
# Out:
# 4

# %% [markdown]
# 콜론(`:`)을 사용하여 부분 시퀀스에 접근할 수 있습니다. 이를 "슬라이싱(slicing)"이라고 부릅니다.

# %%
my_list[1:3]
# Out:
# [2, 'THREE']

# %% [markdown]
# 슬라이싱의 시작은 포함(inclusive)되고 끝은 제외(exclusive)된다는 점에 주의하세요. 따라서 `my_리스트[1:3]`은 인덱스 1과 2의 요소를 가져오고 3은 포함하지 않습니다.

# %% [markdown]
# 문자열도 인덱싱과 슬라이싱에 있어서는 리스트 및 튜플과 동일하게 작동합니다. 문자열을 문자의 시퀀스로 생각하면 쉽습니다.

# %%
alphabet = "abcdefghijklmnopqrstuvwxyz"

# %%
alphabet[0]
# Out:
# 'a'

# %%
alphabet[-1]
# Out:
# 'z'

# %%
alphabet[-3]
# Out:
# 'x'

# %%
alphabet[:5]
# Out:
# 'abcde'

# %%
alphabet[12:20]
# Out:
# 'mnopqrst'

# %% [markdown]
# ### 리스트 메서드
#
# 리스트는 객체이며 데이터를 다루기 위한 메서드(methods)를 가지고 있습니다. 메서드는 함수와 비슷하게 데이터에 특정 연산을 수행하지만, 객체 자체에 정의되어 있으며 마침표(`.`)를 사용하여 접근한다는 점이 다릅니다. 예를 들어, `my_리스트.append(item)`은 `my_리스트`라는 리스트의 끝에 요소를 추가합니다. 더 많은 [리스트 메서드](https://docs.python.org/3/tutorial/datastructures.html#more-on-리스트s)는 공식 문서를 참고하세요.

# %%
primes = [2, 3, 5, 7, 11]
primes
# Out:
# [2, 3, 5, 7, 11]

# %%
len(primes)
# Out:
# 5

# %%
primes.append(13)

# %%
primes
# Out:
# [2, 3, 5, 7, 11, 13]

# %% [markdown]
# ### Sets
#
# Another built-in Python data type is the `set`, which stores an _un-ordered_ 리스트 of _unique_ items. Being unordered, sets do not record element position or order of insertion and so do not support indexing.

# %%
s = {2, 3, 5, 11}
s
# Out:
# {2, 3, 5, 11}

# %%
{1, 2, 3} == {3, 2, 1}
# Out:
# True

# %%
[1, 2, 3] == [3, 2, 1]
# Out:
# False

# %%
s.add(2)  # does nothing
s
# Out:
# {2, 3, 5, 11}

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-c9c96910e542> in <module>
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# Above: throws an error because elements are not ordered and can't be indexing.

# %% [markdown]
# ### Mutable vs. Immutable Types
#
# Strings and 튜플s are immutable types which means they can't be modified. Lists are mutable and we can assign new values for its various entries. This is the main difference between 리스트s and 튜플s.

# %%
names_list = ["Indiana", "Fang", "Linsey"]
names_list
# Out:
# ['Indiana', 'Fang', 'Linsey']

# %%
names_list[0] = "Cool guy"
names_list
# Out:
# ['Cool guy', 'Fang', 'Linsey']

# %%
names_tuple = ("Indiana", "Fang", "Linsey")
names_tuple
# Out:
# ('Indiana', 'Fang', 'Linsey')

# %%
names_tuple[0] = "Not cool guy"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-bd6a1b77b220> in <module>
# ----> 1 names_tuple[0] = "Not cool guy"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Same goes for 문자열s. Once defined we cannot modifiy the characters of the 문자열.

# %%
my_name = "Tom"

# %%
my_name[-1] = "q"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-9bfcf81dbcf0> in <module>
# ----> 1 my_name[-1] = "q"
#
# TypeError: 'str' object does not support item assignment

# %%
x = ([1, 2, 3], 5)

# %%
x[1] = 7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-415ce6bd0126> in <module>
# ----> 1 x[1] = 7
#
# TypeError: 'tuple' object does not support item assignment

# %%
x
# Out:
# ([1, 2, 3], 5)

# %%
x[0][1] = 4

# %%
x
# Out:
# ([1, 4, 3], 5)

# %% [markdown]
# ## 4. 문자열 메서드
# <hr>

# %% [markdown]
# There are various useful 문자열 methods in Python.

# %%
all_caps = "HOW ARE YOU TODAY?"
all_caps
# Out:
# 'HOW ARE YOU TODAY?'

# %%
new_str = all_caps.lower()
new_str
# Out:
# 'how are you today?'

# %% [markdown]
# Note that the method lower doesn't change the original 문자열 but rather returns a new one.

# %%
all_caps
# Out:
# 'HOW ARE YOU TODAY?'

# %% [markdown]
# There are *many* 문자열 methods. Check out the [documentation](https://docs.python.org/3/library/stdtypes.html#문자열-methods).

# %%
all_caps.split()
# Out:
# ['HOW', 'ARE', 'YOU', 'TODAY?']

# %%
all_caps.count("O")
# Out:
# 3

# %% [markdown]
# One can explicitly cast a 문자열 to a 리스트:

# %%
caps_list = list(all_caps)
caps_list
# Out:
# ['H',
#  'O',
#  'W',
#  ' ',
#  'A',
#  'R',
#  'E',
#  ' ',
#  'Y',
#  'O',
#  'U',
#  ' ',
#  'T',
#  'O',
#  'D',
#  'A',
#  'Y',
#  '?']

# %%
"".join(caps_list)
# Out:
# 'HOW ARE YOU TODAY?'

# %%
"-".join(caps_list)
# Out:
# 'H-O-W- -A-R-E- -Y-O-U- -T-O-D-A-Y-?'

# %% [markdown]
# We can also chain multiple methods together (more on this when we get to NumPy and Pandas in later chapters):

# %%
"".join(caps_list).lower().split(" ")
# Out:
# ['how', 'are', 'you', 'today?']

# %% [markdown]
# ### String formatting
#
# Python has ways of creating 문자열s by "filling in the blanks" and formatting them nicely. This is helpful for when you want to print statements that include variables or statements. There are a few ways of doing this but I use and recommend [f-문자열s](https://docs.python.org/3.6/whatsnew/3.6.html#whatsnew36-pep498) which were introduced in Python 3.6. All you need to do is put the letter "f" out the front of your 문자열 and then you can include variables with curly-bracket notation `{}`.

# %%
name = "Newborn Baby"
age = 4 / 12
day = 10
month = 6
year = 2020
template_new = f"Hello, my name is {name}. I am {age:.2f} years old. I was born {day}/{month:02}/{year}."
template_new
# Out:
# 'Hello, my name is Newborn Baby. I am 0.33 years old. I was born 10/06/2020.'

# %% [markdown]
# ```{note} Notes require **no** arguments,
# In the code above, the notation after the colon in my curly braces is for formatting. For example, `:.2f` means, print this variable with 2 decimal places. See format code options [here](https://docs.python.org/3.4/library/문자열.html#format-specification-mini-language).
# ```

# %% [markdown]
# ## 5. 딕셔너리
# <hr>

# %% [markdown]
# A 딕셔너리 is a mapping between key-values pairs and is defined with curly-brackets:

# %%
house = {
    "bedrooms": 3,
    "bathrooms": 2,
    "city": "Vancouver",
    "price": 2499999,
    "date_sold": (1, 3, 2015),
}

condo = {
    "bedrooms": 2,
    "bathrooms": 1,
    "city": "Burnaby",
    "price": 699999,
    "date_sold": (27, 8, 2011),
}

# %% [markdown]
# We can access a specific field of a 딕셔너리 with square brackets:

# %%
house["price"]
# Out:
# 2499999

# %%
condo["city"]
# Out:
# 'Burnaby'

# %% [markdown]
# We can also edit dictionaries (they are mutable):

# %%
condo["price"] = 5  # price already in the dict
condo
# Out:
# {'bedrooms': 2,
#  'bathrooms': 1,
#  'city': 'Burnaby',
#  'price': 5,
#  'date_sold': (27, 8, 2011)}

# %%
condo["flooring"] = "wood"

# %%
condo
# Out:
# {'bedrooms': 2,
#  'bathrooms': 1,
#  'city': 'Burnaby',
#  'price': 5,
#  'date_sold': (27, 8, 2011),
#  'flooring': 'wood'}

# %% [markdown]
# We can also delete fields entirely (though I rarely use this):

# %%
del condo["city"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-138-c9f116276b74> in <module>
# ----> 1 del condo["city"]
#
# KeyError: 'city'

# %%
condo
# Out:
# {'bedrooms': 2,
#  'bathrooms': 1,
#  'price': 5,
#  'date_sold': (27, 8, 2011),
#  'flooring': 'wood'}

# %% [markdown]
# And we can easily add fields:

# %%
condo[5] = 443345

# %%
condo
# Out:
# {'bedrooms': 2,
#  'bathrooms': 1,
#  'price': 5,
#  'date_sold': (27, 8, 2011),
#  'flooring': 'wood',
#  5: 443345}

# %% [markdown]
# Keys may be any immutable data type, even a `튜플`!

# %%
condo[(1, 2, 3)] = 777
condo
# Out:
# {'bedrooms': 2,
#  'bathrooms': 1,
#  'price': 5,
#  'date_sold': (27, 8, 2011),
#  'flooring': 'wood',
#  5: 443345,
#  (1, 2, 3): 777}

# %% [markdown]
# You'll get an error if you try to access a non-existent key:

# %%
condo["not-here"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-ab081f66baa5> in <module>
# ----> 1 condo["not-here"]
#
# KeyError: 'not-here'

# %% [markdown]
# ## 6. 빈 객체들

# %% [markdown]
# Sometimes you'll want to create empty objects that will be filled later on.

# %%
lst = list()  # empty list
lst
# Out:
# []

# %%
lst = []  # empty list
lst
# Out:
# []

# %% [markdown]
# There's no real difference between the two methods above, `[]` is apparently [marginally faster](https://stackoverflow.com/questions/2972212/creating-an-empty-리스트-in-python)...

# %%
tup = tuple()  # empty tuple
tup
# Out:
# ()

# %%
tup = ()  # empty tuple
tup
# Out:
# ()

# %%
dic = dict()  # empty dict
dic
# Out:
# {}

# %%
dic = {}  # empty dict
dic
# Out:
# {}

# %%
st = set()  # empty set
st
# Out:
# set()

# %% [markdown]
# ## 7. 조건문
# <hr>

# %% [markdown]
# [Conditional statements](https://docs.python.org/3/tutorial/controlflow.html) allow us to write programs where only certain blocks of code are executed depending on the state of the program. Let's look at some examples and take note of the keywords, syntax and indentation.

# %%
name = "Tom"

if name.lower() == "tom":
    print("That's my name too!")
elif name.lower() == "santa":
    print("That's a funny name.")
else:
    print(f"Hello {name}! That's a cool name!")
print("Nice to meet you!")
# Out:
# That's my name too!
# Nice to meet you!

# %% [markdown]
# The main points to notice:
# - Use keywords `if`, `elif` and `else`
# - The colon `:` ends each conditional expression
# - Indentation (by 4 empty space) defines code blocks
# - In an `if` statement, the first block whose conditional statement returns `True` is executed and the program exits the `if` block
# - `if` statements don't necessarily need `elif` or `else`
# - `elif` lets us check several conditions
# - `else` lets us evaluate a default block if all other conditions are `False`
# - the end of the entire `if` statement is where the indentation returns to the same level as the first `if` keyword

# %% [markdown]
# If statements can also be **nested** inside of one another:

# %%
name = "Super Tom"

if name.lower() == "tom":
    print("That's my name too!")
elif name.lower() == "santa":
    print("That's a funny name.")
else:
    print(f"Hello {name}! That's a cool name.")
    if name.lower().startswith("super"):
        print("Do you really have superpowers?")

print("Nice to meet you!")
# Out:
# Hello Super Tom! That's a cool name.
# Do you really have superpowers?
# Nice to meet you!

# %% [markdown]
# ### Inline if/else

# %% [markdown]
# We can write simple `if` statements "inline", i.e., in a single line, for simplicity.

# %%
words = ["the", "list", "of", "words"]

x = "long list" if len(words) > 10 else "short list"
x
# Out:
# 'short list'

# %%
if len(words) > 10:
    x = "long list"
else:
    x = "short list"

# %%
x
# Out:
# 'short list'

# %% [markdown]
# ### Truth Value Testing

# %% [markdown]
# Any object can be tested for "truth" in Python, for use in `if` and `while` (next chapter) statements.
# - `True` values: all objects return `True` unless they are a `bool` object with value `False` or have `len()` == 0
# - `False` values: `None`, `False`, `0`, empty sequences and collections: `''`, `()`, `[]`, `{}`, `set()`
#
# ::: {.callout-tip}
# 더 자세한 내용은 [공식 문서](https://docs.python.org/3/library/stdtypes.html#truth-value-testing)에서 확인할 수 있습니다.
# :::

# %%
x = 1

if x:
    print("I'm truthy!")
else:
    print("I'm falsey!")
# Out:
# I'm truthy!

# %%
x = False

if x:
    print("I'm truthy!")
else:
    print("I'm falsey!")
# Out:
# I'm falsey!

# %%
x = []

if x:
    print("I'm truthy!")
else:
    print("I'm falsey!")
# Out:
# I'm falsey!

# %% [markdown]
# ### Short-circuiting

# %% [markdown]
# Python supports a concept known as "short-circuting". This is the automatic stopping of the execution of 불리언 operation if the truth value of expression has already been determined.

# %%
fake_variable  # not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-159-38b1451e4717> in <module>
# ----> 1 fake_variable  # not defined
#
# NameError: name 'fake_variable' is not defined

# %%
True or fake_variable
# Out:
# True

# %%
True and fake_variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-161-a7196cc665d5> in <module>
# ----> 1 True and fake_variable
#
# NameError: name 'fake_variable' is not defined

# %%
False and fake_variable
# Out:
# False

# %% [markdown]
# |Expression|Result|세부 사항|
# |---|---|---|
# |A or B|A가 `True`이면 A, 그렇지 않으면 B|A가 `False`인 경우에만 B가 실행됨|
# |A and B|A가 `False`이면 A, 그렇지 않으면 B|A가 `True`인 경우에만 B가 실행됨|
